# %% [markdown]
# # Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import json
import tweepy
from tweepy import OAuthHandler
from timeit import default_timer as timer

# %% [markdown]
# # Gathering

# %%
tweet_arch = pd.read_csv('twitter-archive-enhanced.csv')

# %%
url = ' https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'

response = requests.get(url)
with open(url.split('/')[-1], 'wb') as file:
        file.write(response.content)

# %%
image_pred = pd.read_csv('image-predictions.tsv', sep='\t')

# %%
consumer_key = 'HIDDEN'
consumer_secret = 'HIDDEN'
access_token = 'HIDDEN'
access_secret = 'HIDDEN'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
tweet_ids = tweet_arch.tweet_id.values
len(tweet_ids)
# Out:
# 2356

# %%
count = 0
fails_dict = {}
start = timer()

with open('tweet_json.txt', 'w') as outfile:
    for tweet_id in tweet_ids:
        count += 1
        print(str(count) + ": " + str(tweet_id))
        try:
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            print("Success")
            json.dump(tweet._json, outfile)
            outfile.write('\n')
            
        except tweepy.TweepyException as e:
            print("Fail")
            fails_dict[tweet_id]
            pass
end = timer()
print(end - start)
print(fails_dict)
# Out:
# 1: 892420643555336193
# Fail
# ---------------------------------------------------------------------------
# Unauthorized                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11128/1774546668.py in <module>
#       9         try:
# ---> 10             tweet = api.get_status(tweet_id, tweet_mode='extended')
#      11             print("Success")
#
# ~\anaconda3\lib\site-packages\tweepy\api.py in wrapper(*args, **kwargs)
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
#
# ~\anaconda3\lib\site-packages\tweepy\api.py in get_status(self, id, **kwargs)
#     899                 'include_ext_alt_text', 'include_card_uri'
# --> 900             ), id=id, **kwargs
#     901         )
#
# ...

# %%
with open('tweet-json.txt', 'r') as file:
    df_list = []
    for line in file:
        data = json.loads(line)
        for key, value in data.items():
            if key == 'id':
                t_id = value
            if key == 'retweet_count':
                r_count = value
            if key == 'favorite_count':
                f_count = value
            if key == 'expanded_url':
                url = value
        df_list.append({'tweet_id': t_id,
                        'retweet_count': r_count,
                        'favorite_count': f_count,
                        'expanded_url': url})

# %%
tweet_json = pd.DataFrame(df_list, columns = ['tweet_id', 'retweet_count', 'favorite_count', 'expanded_url'])

# %% [markdown]
# # Accessing

# %%
tweet_arch.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
image_pred.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
tweet_json.head()
# Out:
#              tweet_id  retweet_count  favorite_count  \
# 0  892420643555336193           8853           39467
# 1  892177421306343426           6514           33819
# 2  891815181378084864           4328           25461
# 3  891689557279858688           8964           42908
# 4  891327558926688256           9774           41048
#
#                                         expanded_url
# 0   https://d17h27t6h515a5.cloudfront.net/topher/...
# 1   https://d17h27t6h515a5.cloudfront.net/topher/...
# 2   https://d17h27t6h515a5.cloudfront.net/topher/...
# 3   https://d17h27t6h515a5.cloudfront.net/topher/...
# 4   https://d17h27t6h515a5.cloudfront.net/topher/...

# %%
tweet_arch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2356 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2356 non-null   object
#  4   source                      2356 non-null   object
#  5   text                        2356 non-null   object
#  6   retweeted_status_id         181 non-null    float64
#  7   retweeted_status_user_id    181 non-null    float64
#  8   retweeted_status_timestamp  181 non-null    object
#  9   expanded_urls               2297 non-null   object
#  10  rating_numerator            2356 non-null   int64
#  11  rating_denominator          2356 non-null   int64
#  12  name                        2356 non-null   object
# ...

# %%
image_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   int64
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
tweet_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2354 non-null   int64
#  1   retweet_count   2354 non-null   int64
#  2   favorite_count  2354 non-null   int64
#  3   expanded_url    2354 non-null   object
# dtypes: int64(3), object(1)
# memory usage: 73.7+ KB

# %%
tweet_arch.sample(5)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 590   799297110730567681                    NaN                  NaN
# 1210  715680795826982913                    NaN                  NaN
# 1156  724771698126512129                    NaN                  NaN
# 2033  671744970634719232                    NaN                  NaN
# 1871  675147105808306176                    NaN                  NaN
#
#                       timestamp  \
# 590   2016-11-17 17:04:16 +0000
# 1210  2016-03-31 23:22:53 +0000
# 1156  2016-04-26 01:26:53 +0000
# 2033  2015-12-01 17:37:36 +0000
# 1871  2015-12-11 02:56:28 +0000
#
#                                                  source  \
# 590   <a href="http://twitter.com/download/iphone" r...
# 1210  <a href="http://twitter.com/download/iphone" r...
# 1156  <a href="http://twitter.com/download/iphone" r...
# 2033  <a href="http://twitter.com/download/iphone" r...
# 1871  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
image_pred.sample(5)
# Out:
#                 tweet_id                                          jpg_url  \
# 1965  867421006826221569  https://pbs.twimg.com/media/DAmyy8FXYAIH8Ty.jpg
# 510   676146341966438401  https://pbs.twimg.com/media/CWIngp5WEAAJOy3.jpg
# 1986  872486979161796608  https://pbs.twimg.com/media/DBuyRlTUwAAYhG9.jpg
# 1337  758405701903519748  https://pbs.twimg.com/media/CoZl9fXWgAMox0n.jpg
# 597   679530280114372609  https://pbs.twimg.com/media/CW4tL1vWcAIw1dw.jpg
#
#       img_num                        p1   p1_conf  p1_dog               p2  \
# 1965        1                Eskimo_dog  0.616457    True   Siberian_husky
# 510         1       Irish_water_spaniel  0.388332    True  standard_poodle
# 1986        1                  Pembroke  0.931861    True         Cardigan
# 1337        4  Chesapeake_Bay_retriever  0.702954    True           laptop
# 597         1                 dalmatian  0.750256    True           jaguar
#
#        p2_conf  p2_dog          p3   p3_conf  p3_dog
# ...

# %%
tweet_json.sample(4)
# Out:
#                 tweet_id  retweet_count  favorite_count  \
# 1070  739979191639244800           6719           21898
# 699   786233965241827333           5571           17178
# 1976  672984142909456390            593            1338
# 1819  676582956622721024            312            1310
#
#                                            expanded_url
# 1070   https://d17h27t6h515a5.cloudfront.net/topher/...
# 699    https://d17h27t6h515a5.cloudfront.net/topher/...
# 1976   https://d17h27t6h515a5.cloudfront.net/topher/...
# 1819   https://d17h27t6h515a5.cloudfront.net/topher/...

# %%
tweet_arch['rating_denominator'].value_counts()
# Out:
# 10     2333
# 11        3
# 50        3
# 20        2
# 80        2
# 70        1
# 7         1
# 15        1
# 150       1
# 170       1
# 0         1
# 90        1
# 40        1
# 130       1
# 110       1
# 16        1
# 120       1
# 2         1
# Name: rating_denominator, dtype: int64

# %%
tweet_arch[tweet_arch['rating_denominator'] != 10]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 313   835246439529840640           8.352460e+17         2.625958e+07
# 342   832088576586297345           8.320875e+17         3.058208e+07
# 433   820690176645140481                    NaN                  NaN
# 516   810984652412424192                    NaN                  NaN
# 784   775096608509886464                    NaN                  NaN
# 902   758467244762497024                    NaN                  NaN
# 1068  740373189193256964                    NaN                  NaN
# 1120  731156023742988288                    NaN                  NaN
# 1165  722974582966214656                    NaN                  NaN
# 1202  716439118184652801                    NaN                  NaN
# 1228  713900603437621249                    NaN                  NaN
# 1254  710658690886586372                    NaN                  NaN
# 1274  709198395643068416                    NaN                  NaN
# ...

# %% [markdown]
# ### Quality Issues
#
# **tweet_arch table**
# - retweet data is included in dataset which can skew analysis on original data
# - 'retweeted_status_id', 'retweeted_status_user_id'and 'retweeted_status_timestamp' have only 181 entries
# - 'in_reply_to_status_id' and 'in_reply_to_user_id' have only 78 entries
# - 'tweet_id' in all 3 datasets are integers
# - 'expanded_urls' has a few missing entries
# - 'timestamp' is a string type
# - 'rating_denominator' has a 0 value
#
#
# **image_pred table**
# - predictions don't march in all 3 predictions column
#
# ### Tidiness Issues
# - The tweet_arch table and the tweet_json table have the same type of observational unit
# - The dog stages in the tweet_arch table are in seperate columns

# %% [markdown]
# # Cleaning

# %%
tweet_clean = tweet_arch.copy()
image_clean = image_pred.copy()
tweet_j = tweet_json.copy()

# %% [markdown]
# ### Quality

# %% [markdown]
# #### Define
# Removing all retweet data that can skew analysis results

# %% [markdown]
# #### Code

# %%
tweet_clean = tweet_clean[tweet_clean['retweeted_status_id'].isnull()]

# %% [markdown]
# #### Test

# %%
tweet_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   tweet_id                    2175 non-null   int64
#  1   in_reply_to_status_id       78 non-null     float64
#  2   in_reply_to_user_id         78 non-null     float64
#  3   timestamp                   2175 non-null   object
#  4   source                      2175 non-null   object
#  5   text                        2175 non-null   object
#  6   retweeted_status_id         0 non-null      float64
#  7   retweeted_status_user_id    0 non-null      float64
#  8   retweeted_status_timestamp  0 non-null      object
#  9   expanded_urls               2117 non-null   object
#  10  rating_numerator            2175 non-null   int64
#  11  rating_denominator          2175 non-null   int64
#  12  name                        2175 non-null   object
# ...

# %% [markdown]
# Now all the retweet parameters are null which means that all retweet data in the dataset has been removed.

# %% [markdown]
# #### Define
# Droping the 'retweeted_status_timestamp', 'retweeted_status_user_id' and 'retweeted_status_id' columns in the `tweet_clean` table since they had only 181 entries to begin with and now we revomed the retweets data from the dataset they are null variables.

# %% [markdown]
# #### Code

# %%
tweet_clean = tweet_clean.drop('retweeted_status_timestamp', axis = 1)
tweet_clean = tweet_clean.drop('retweeted_status_user_id', axis = 1)
tweet_clean = tweet_clean.drop('retweeted_status_id', axis = 1)

# %% [markdown]
# #### Test

# %%
tweet_clean.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo'],
#       dtype='object')

# %% [markdown]
# #### Define
# Droping the 'in_reply_to_user_id' and 'in_reply_to_status_id' columns in the `tweet_clean` table since they have only 78 entries.

# %% [markdown]
# #### Code

# %%
tweet_clean = tweet_clean.drop('in_reply_to_user_id', axis = 1)
tweet_clean = tweet_clean.drop('in_reply_to_status_id', axis = 1)

# %% [markdown]
# #### Test

# %%
tweet_clean.columns
# Out:
# Index(['tweet_id', 'timestamp', 'source', 'text', 'expanded_urls',
#        'rating_numerator', 'rating_denominator', 'name', 'doggo', 'floofer',
#        'pupper', 'puppo'],
#       dtype='object')

# %% [markdown]
# #### Define
# Change the type of the 'tweet_id' in all 3 datasets from integers to object using the astype() function

# %% [markdown]
# #### Code

# %%
tweet_clean = tweet_clean.astype({'tweet_id':'str'})
tweet_j = tweet_j.astype({'tweet_id':'str'})
image_clean = image_clean.astype({'tweet_id':'str'})

# %% [markdown]
# #### Test

# %%
tweet_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2175 non-null   object
#  1   timestamp           2175 non-null   object
#  2   source              2175 non-null   object
#  3   text                2175 non-null   object
#  4   expanded_urls       2117 non-null   object
#  5   rating_numerator    2175 non-null   int64
#  6   rating_denominator  2175 non-null   int64
#  7   name                2175 non-null   object
#  8   doggo               2175 non-null   object
#  9   floofer             2175 non-null   object
#  10  pupper              2175 non-null   object
#  11  puppo               2175 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 220.9+ KB

# %%
tweet_j.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tweet_id        2354 non-null   object
#  1   retweet_count   2354 non-null   int64
#  2   favorite_count  2354 non-null   int64
#  3   expanded_url    2354 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 73.7+ KB

# %%
image_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tweet_id  2075 non-null   object
#  1   jpg_url   2075 non-null   object
#  2   img_num   2075 non-null   int64
#  3   p1        2075 non-null   object
#  4   p1_conf   2075 non-null   float64
#  5   p1_dog    2075 non-null   bool
#  6   p2        2075 non-null   object
#  7   p2_conf   2075 non-null   float64
#  8   p2_dog    2075 non-null   bool
#  9   p3        2075 non-null   object
#  10  p3_conf   2075 non-null   float64
#  11  p3_dog    2075 non-null   bool
# dtypes: bool(3), float64(3), int64(1), object(5)
# memory usage: 152.1+ KB

# %% [markdown]
# #### Define
# Using the values from 'expanded_url' in the `tweet_j` table to fill the missing rows of the 'expanded_urls' column in the `tweet_clean` table.

# %% [markdown]
# #### Code

# %%
tweet_clean['expanded_urls'] = tweet_clean['expanded_urls'].fillna(value=tweet_j['expanded_url'])

# %% [markdown]
# #### Test

# %%
tweet_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2175 non-null   object
#  1   timestamp           2175 non-null   object
#  2   source              2175 non-null   object
#  3   text                2175 non-null   object
#  4   expanded_urls       2175 non-null   object
#  5   rating_numerator    2175 non-null   int64
#  6   rating_denominator  2175 non-null   int64
#  7   name                2175 non-null   object
#  8   doggo               2175 non-null   object
#  9   floofer             2175 non-null   object
#  10  pupper              2175 non-null   object
#  11  puppo               2175 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 220.9+ KB

# %% [markdown]
# #### Define
# Convert the 'timestamp' column in the `tweet_clean` table to a datetime type

# %% [markdown]
# #### Code

# %%
tweet_clean['timestamp'] = pd.to_datetime(tweet_clean['timestamp'])

# %% [markdown]
# #### Test

# %%
tweet_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2355
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2175 non-null   object
#  1   timestamp           2175 non-null   datetime64[ns, UTC]
#  2   source              2175 non-null   object
#  3   text                2175 non-null   object
#  4   expanded_urls       2175 non-null   object
#  5   rating_numerator    2175 non-null   int64
#  6   rating_denominator  2175 non-null   int64
#  7   name                2175 non-null   object
#  8   doggo               2175 non-null   object
#  9   floofer             2175 non-null   object
#  10  pupper              2175 non-null   object
#  11  puppo               2175 non-null   object
# dtypes: datetime64[ns, UTC](1), int64(2), object(9)
# memory usage: 220.9+ KB

# %% [markdown]
# #### Define
# Removing the 0 value from the 'rating_denominator' since the values cannot be deducted from the pattern of non 10 denominators.

# %% [markdown]
# #### Code

# %%
tweet_clean = tweet_clean[tweet_clean['rating_denominator'] != 0]

# %% [markdown]
# ### Test

# %%
tweet_clean['rating_denominator'].value_counts()
# Out:
# 10     2153
# 50        3
# 11        2
# 20        2
# 80        2
# 70        1
# 7         1
# 150       1
# 170       1
# 15        1
# 90        1
# 40        1
# 130       1
# 110       1
# 16        1
# 120       1
# 2         1
# Name: rating_denominator, dtype: int64

# %% [markdown]
# #### Define
# Selecting only obsevations where all 3 predictions for dog is True ie p1_dog, p2_dog and p3_dog equals True.

# %% [markdown]
# #### Code

# %%
image_clean = image_clean[(image_clean['p1_dog'] == True) & (image_clean['p2_dog'] == True) & (image_clean['p3_dog'] == True)]

# %% [markdown]
# #### Test

# %%
assert image_clean['p1_dog'].all() == True
assert image_clean['p2_dog'].all() == True
assert image_clean['p3_dog'].all() == True

# %% [markdown]
# ### Tidiness

# %% [markdown]
# #### Define
# Merge the `tweet_j` table with the `tweet_clean` table, joining on tweet_id.

# %% [markdown]
# #### Code

# %%
tweet_clean = pd.merge(tweet_clean, tweet_j, on = 'tweet_id', how = 'left')

# %% [markdown]
# #### Test

# %%
tweet_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2174 entries, 0 to 2173
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2174 non-null   object
#  1   timestamp           2174 non-null   datetime64[ns, UTC]
#  2   source              2174 non-null   object
#  3   text                2174 non-null   object
#  4   expanded_urls       2174 non-null   object
#  5   rating_numerator    2174 non-null   int64
#  6   rating_denominator  2174 non-null   int64
#  7   name                2174 non-null   object
#  8   doggo               2174 non-null   object
#  9   floofer             2174 non-null   object
#  10  pupper              2174 non-null   object
#  11  puppo               2174 non-null   object
#  12  retweet_count       2174 non-null   int64
#  13  favorite_count      2174 non-null   int64
#  14  expanded_url        2174 non-null   object
# ...

# %% [markdown]
# #### Define
# Drop the 'expanded_url' column since it is not needed in the `tweet_clean` table

# %% [markdown]
# #### Code

# %%
tweet_clean = tweet_clean.drop('expanded_url', axis = 1)

# %% [markdown]
# #### Test

# %%
tweet_clean.columns
# Out:
# Index(['tweet_id', 'timestamp', 'source', 'text', 'expanded_urls',
#        'rating_numerator', 'rating_denominator', 'name', 'doggo', 'floofer',
#        'pupper', 'puppo', 'retweet_count', 'favorite_count'],
#       dtype='object')

# %% [markdown]
# #### Define
# Melt the 'doggo', 'floofer', 'pupper', 'puppo' columns in the `tweet_clean` table into dog_stage column

# %% [markdown]
# #### Code

# %%
id_vars=['tweet_id', 'timestamp', 'source', 'text', 'expanded_urls',
       'rating_numerator', 'rating_denominator', 'name', 'retweet_count', 'favorite_count']

tweet_clean = pd.melt(tweet_clean, id_vars=id_vars, value_name='dog_stage')
tweet_clean = tweet_clean.drop('variable', axis=1)

# %% [markdown]
# #### Test

# %%
tweet_clean.head()
# Out:
#              tweet_id                 timestamp  \
# 0  892420643555336193 2017-08-01 16:23:56+00:00
# 1  892177421306343426 2017-08-01 00:17:27+00:00
# 2  891815181378084864 2017-07-31 00:18:03+00:00
# 3  891689557279858688 2017-07-30 15:58:51+00:00
# 4  891327558926688256 2017-07-29 16:00:24+00:00
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
# ...

# %% [markdown]
# #### Define
# Drop Duplicates created from using melt() function.

# %% [markdown]
# #### Code

# %%
tweet_clean.drop_duplicates(inplace=True)

# %%
tweet_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2530 entries, 0 to 7426
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2530 non-null   object
#  1   timestamp           2530 non-null   datetime64[ns, UTC]
#  2   source              2530 non-null   object
#  3   text                2530 non-null   object
#  4   expanded_urls       2530 non-null   object
#  5   rating_numerator    2530 non-null   int64
#  6   rating_denominator  2530 non-null   int64
#  7   name                2530 non-null   object
#  8   retweet_count       2530 non-null   int64
#  9   favorite_count      2530 non-null   int64
#  10  dog_stage           2530 non-null   object
# dtypes: datetime64[ns, UTC](1), int64(4), object(6)
# memory usage: 237.2+ KB

# %%
tweet_clean.sample(10)
# Out:
#                 tweet_id                 timestamp  \
# 1862  671538301157904385 2015-12-01 03:56:22+00:00
# 370   819238181065359361 2017-01-11 17:42:57+00:00
# 442   808001312164028416 2016-12-11 17:31:39+00:00
# 96    871762521631449091 2017-06-05 16:15:56+00:00
# 1504  681679526984871937 2015-12-29 03:33:58+00:00
# 337   824663926340194305 2017-01-26 17:02:56+00:00
# 131   863079547188785154 2017-05-12 17:12:53+00:00
# 1185  702684942141153280 2016-02-25 02:42:00+00:00
# 996   720043174954147842 2016-04-13 00:17:25+00:00
# 1918  670727704916926465 2015-11-28 22:15:21+00:00
#
#                                                  source  \
# 1862  <a href="http://twitter.com/download/iphone" r...
# 370   <a href="http://twitter.com" rel="nofollow">Tw...
# 442   <a href="http://twitter.com/download/iphone" r...
# 96    <a href="http://twitter.com/download/iphone" r...
# 1504  <a href="http://twitter.com/download/iphone" r...
# 337   <a href="http://twitter.com/download/iphone" r...
# ...

# %%
tweet_clean.to_csv('twitter_archive_master.csv')

# %% [markdown]
# # Analyse

# %% [markdown]
# ### Insight (1)

# %%
tweet_clean.dog_stage.value_counts()
# Out:
# None       2174
# pupper      234
# doggo        87
# puppo        25
# floofer      10
# Name: dog_stage, dtype: int64

# %% [markdown]
# **We can see that most tweets in this dataset don't add a dog stage and for those that add a dog stage, it's mostly when the dog is in the pupper stage.**

# %% [markdown]
# ### Insight (2)

# %%
retweet_g = tweet_clean.groupby('dog_stage')['retweet_count'].mean()
retweet_g
# Out:
# dog_stage
# None       2759.217571
# doggo      6189.655172
# floofer    4083.600000
# pupper     2522.401709
# puppo      6847.040000
# Name: retweet_count, dtype: float64

# %% [markdown]
# **On average puppo has the most number of retweet count in our dataset.**

# %% [markdown]
# ### Insight (3)

# %%
favorite_g = tweet_clean.groupby('dog_stage')['favorite_count'].mean()
favorite_g
# Out:
# dog_stage
# None        8749.006900
# doggo      17108.804598
# floofer    11674.900000
# pupper      7385.705128
# puppo      21871.080000
# Name: favorite_count, dtype: float64

# %% [markdown]
# **On average puppo also has the most number of favorites in our dataset.**

# %% [markdown]
# # Visualization

# %%
stage_tweets = tweet_clean[tweet_clean['dog_stage'] != 'None']

g = sns.countplot(data=stage_tweets, x = 'dog_stage')
g.set(title = 'Distribution of Dog Stages');
plt.savefig('Distribution of Dog Stages.png')

# %%
g = sns.barplot(data= stage_tweets, x = 'dog_stage', y = 'rating_numerator')
g.set(title = 'Distribution of Ratings for each Dog Stage');
plt.savefig('Distribution of Ratings for each Dog Stage.png')

# %% [markdown]
# **The 'We rate dogs' admin seems to give dogs in the puppo stage a higher rating on average.**
